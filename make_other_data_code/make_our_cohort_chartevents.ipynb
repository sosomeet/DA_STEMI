# %%
import pandas as pd
from pathlib import Path

# ---------------------------
# 0. 파일 경로 설정
# ---------------------------
# 너의 로컬 경로에 맞게 수정해서 쓰면 됨
COHORT_PATH = Path("./cohort/cohort_ver50_only_subject_id.csv")   # subject_id만 있는 파일
CHARTEVENTS_PATH = Path("../../data/MIMIC4-hosp-icu/chartevents.csv")  # MIMIC-IV ICU chartevents
OUT_PATH = Path("../../data/MIMIC4-hosp-icu/cohort_ver50_chartevents.csv")         # 출력 파일

# ---------------------------
# 1. cohort subject_id 로딩
# ---------------------------
df_sub = pd.read_csv(COHORT_PATH)

# subject_id 컬럼 이름이 다르면 여기 수정
subject_ids = set(df_sub["subject_id"].unique())

print(f"[INFO] cohort subject_id 개수: {len(subject_ids)}")

# ---------------------------
# 2. chartevents에서 HR / BP 추출
# ---------------------------
HR_ITEMID = 220045   # Heart Rate
MBP_ITEMID = 220052  # Mean Blood Pressure (Non-invasive)

usecols = [
    "subject_id",
    "hadm_id",
    "stay_id",
    "charttime",
    "itemid",
    "valuenum",
]

# 메모리 절약을 위해 chunk 단위로 읽기
chunksize = 1_000_000

filtered_chunks = []

for i, chunk in enumerate(
    pd.read_csv(
        CHARTEVENTS_PATH,
        usecols=usecols,
        chunksize=chunksize,
        dtype={
            "subject_id": "int32",
            "hadm_id": "Int32",
            "stay_id": "Int32",
            "itemid": "int32",
            "valuenum": "float32",
        }
    )
):
    # 1) cohort subject_id만 남기기
    chunk = chunk[chunk["subject_id"].isin(subject_ids)]
    if chunk.empty:
        continue

    # 2) HR / Mean BP itemid만 남기기
    chunk = chunk[chunk["itemid"].isin([HR_ITEMID, MBP_ITEMID])]
    if chunk.empty:
        continue

    # 3) 유효 값만
    chunk = chunk[chunk["valuenum"].notna()]
    if chunk.empty:
        continue

    # 4) itemid를 변수 이름으로 매핑
    chunk["variable_name"] = chunk["itemid"].map({
        HR_ITEMID: "heart_rate",
        MBP_ITEMID: "mean_bp",
    })

    filtered_chunks.append(chunk)

    print(f"[INFO] chunk {i} 처리 완료, 현재 누적 rows: {sum(len(c) for c in filtered_chunks)}")

# ---------------------------
# 3. 결과 병합 및 저장
# ---------------------------
if filtered_chunks:
    df_vitals = pd.concat(filtered_chunks, ignore_index=True)
    # 정렬 (선택)
    df_vitals = df_vitals.sort_values(["subject_id", "hadm_id", "charttime"])

    df_vitals.to_csv(OUT_PATH, index=False)
    print(f"[DONE] 최종 vitals 저장 완료: {OUT_PATH} (rows={len(df_vitals)})")
else:
    print("[WARN] 필터에 걸리는 HR/BP 레코드가 없습니다.")
# Out:
# [INFO] cohort subject_id 개수: 1878
# [INFO] chunk 0 처리 완료, 현재 누적 rows: 235
# [INFO] chunk 2 처리 완료, 현재 누적 rows: 395
# [INFO] chunk 3 처리 완료, 현재 누적 rows: 1308
# [INFO] chunk 5 처리 완료, 현재 누적 rows: 1627
# [INFO] chunk 7 처리 완료, 현재 누적 rows: 2061
# [INFO] chunk 8 처리 완료, 현재 누적 rows: 2399
# [INFO] chunk 10 처리 완료, 현재 누적 rows: 3004
# [INFO] chunk 11 처리 완료, 현재 누적 rows: 5038
# [INFO] chunk 12 처리 완료, 현재 누적 rows: 5937
# [INFO] chunk 13 처리 완료, 현재 누적 rows: 5952
# [INFO] chunk 14 처리 완료, 현재 누적 rows: 6529
# [INFO] chunk 15 처리 완료, 현재 누적 rows: 6856
# [INFO] chunk 16 처리 완료, 현재 누적 rows: 6998
# [INFO] chunk 17 처리 완료, 현재 누적 rows: 7639
# [INFO] chunk 18 처리 완료, 현재 누적 rows: 7804
# [INFO] chunk 19 처리 완료, 현재 누적 rows: 8190
# [INFO] chunk 20 처리 완료, 현재 누적 rows: 8246
# [INFO] chunk 21 처리 완료, 현재 누적 rows: 9510
# [INFO] chunk 22 처리 완료, 현재 누적 rows: 10244
# [INFO] chunk 23 처리 완료, 현재 누적 rows: 12308
# [INFO] chunk 24 처리 완료, 현재 누적 rows: 12459
# [INFO] chunk 25 처리 완료, 현재 누적 rows: 12630
# [INFO] chunk 26 처리 완료, 현재 누적 rows: 13853
# [INFO] chunk 27 처리 완료, 현재 누적 rows: 14216
# [INFO] chunk 29 처리 완료, 현재 누적 rows: 14243
# [INFO] chunk 30 처리 완료, 현재 누적 rows: 16542
# [INFO] chunk 31 처리 완료, 현재 누적 rows: 16573
# [INFO] chunk 32 처리 완료, 현재 누적 rows: 17337
# [INFO] chunk 33 처리 완료, 현재 누적 rows: 17691
# [INFO] chunk 34 처리 완료, 현재 누적 rows: 17781
# [INFO] chunk 35 처리 완료, 현재 누적 rows: 18170
# [INFO] chunk 36 처리 완료, 현재 누적 rows: 18972
# [INFO] chunk 37 처리 완료, 현재 누적 rows: 19163
# [INFO] chunk 38 처리 완료, 현재 누적 rows: 20184
# [INFO] chunk 39 처리 완료, 현재 누적 rows: 20811
# [INFO] chunk 40 처리 완료, 현재 누적 rows: 21329
# [INFO] chunk 41 처리 완료, 현재 누적 rows: 21797
# [INFO] chunk 42 처리 완료, 현재 누적 rows: 22032
# [INFO] chunk 43 처리 완료, 현재 누적 rows: 22717
# [INFO] chunk 44 처리 완료, 현재 누적 rows: 23074
# [INFO] chunk 45 처리 완료, 현재 누적 rows: 23081
# [INFO] chunk 46 처리 완료, 현재 누적 rows: 23715
# [INFO] chunk 47 처리 완료, 현재 누적 rows: 24149
# [INFO] chunk 48 처리 완료, 현재 누적 rows: 24478
# [INFO] chunk 49 처리 완료, 현재 누적 rows: 24742
# [INFO] chunk 50 처리 완료, 현재 누적 rows: 25097
# [INFO] chunk 51 처리 완료, 현재 누적 rows: 26041
# [INFO] chunk 52 처리 완료, 현재 누적 rows: 26051
# [INFO] chunk 53 처리 완료, 현재 누적 rows: 26191
# [INFO] chunk 54 처리 완료, 현재 누적 rows: 30112
# [INFO] chunk 55 처리 완료, 현재 누적 rows: 32052
# [INFO] chunk 56 처리 완료, 현재 누적 rows: 32403
# [INFO] chunk 57 처리 완료, 현재 누적 rows: 32689
# [INFO] chunk 58 처리 완료, 현재 누적 rows: 32829
# [INFO] chunk 59 처리 완료, 현재 누적 rows: 33025
# [INFO] chunk 60 처리 완료, 현재 누적 rows: 34047
# [INFO] chunk 61 처리 완료, 현재 누적 rows: 34672
# [INFO] chunk 62 처리 완료, 현재 누적 rows: 34762
# [INFO] chunk 63 처리 완료, 현재 누적 rows: 36050
# [INFO] chunk 64 처리 완료, 현재 누적 rows: 37004
# [INFO] chunk 65 처리 완료, 현재 누적 rows: 37320
# [INFO] chunk 66 처리 완료, 현재 누적 rows: 38387
# [INFO] chunk 67 처리 완료, 현재 누적 rows: 38715
# [INFO] chunk 68 처리 완료, 현재 누적 rows: 39563
# [INFO] chunk 69 처리 완료, 현재 누적 rows: 39654
# [INFO] chunk 70 처리 완료, 현재 누적 rows: 39781
# [INFO] chunk 71 처리 완료, 현재 누적 rows: 40165
# [INFO] chunk 72 처리 완료, 현재 누적 rows: 40237
# [INFO] chunk 73 처리 완료, 현재 누적 rows: 41164
# [INFO] chunk 74 처리 완료, 현재 누적 rows: 41365
# [INFO] chunk 75 처리 완료, 현재 누적 rows: 41428
# [INFO] chunk 76 처리 완료, 현재 누적 rows: 43827
# [INFO] chunk 77 처리 완료, 현재 누적 rows: 44888
# [INFO] chunk 78 처리 완료, 현재 누적 rows: 44932
# [INFO] chunk 79 처리 완료, 현재 누적 rows: 45282
# [INFO] chunk 80 처리 완료, 현재 누적 rows: 46033
# [INFO] chunk 81 처리 완료, 현재 누적 rows: 46294
# [INFO] chunk 82 처리 완료, 현재 누적 rows: 46916
# [INFO] chunk 83 처리 완료, 현재 누적 rows: 48624
# [INFO] chunk 84 처리 완료, 현재 누적 rows: 50347
# [INFO] chunk 85 처리 완료, 현재 누적 rows: 51022
# [INFO] chunk 87 처리 완료, 현재 누적 rows: 51947
# [INFO] chunk 88 처리 완료, 현재 누적 rows: 52265
# [INFO] chunk 89 처리 완료, 현재 누적 rows: 52291
# [INFO] chunk 90 처리 완료, 현재 누적 rows: 52438
# [INFO] chunk 91 처리 완료, 현재 누적 rows: 53084
# [INFO] chunk 92 처리 완료, 현재 누적 rows: 53449
# [INFO] chunk 93 처리 완료, 현재 누적 rows: 53469
# [INFO] chunk 94 처리 완료, 현재 누적 rows: 53636
# [INFO] chunk 95 처리 완료, 현재 누적 rows: 53841
# [INFO] chunk 96 처리 완료, 현재 누적 rows: 54158
# [INFO] chunk 97 처리 완료, 현재 누적 rows: 54709
# [INFO] chunk 98 처리 완료, 현재 누적 rows: 54779
# [INFO] chunk 99 처리 완료, 현재 누적 rows: 56101
# [INFO] chunk 100 처리 완료, 현재 누적 rows: 56214
# [INFO] chunk 101 처리 완료, 현재 누적 rows: 56940
# [INFO] chunk 102 처리 완료, 현재 누적 rows: 58233
# [INFO] chunk 103 처리 완료, 현재 누적 rows: 59043
# [INFO] chunk 104 처리 완료, 현재 누적 rows: 59837
# [INFO] chunk 105 처리 완료, 현재 누적 rows: 60134
# [INFO] chunk 106 처리 완료, 현재 누적 rows: 60521
# [INFO] chunk 107 처리 완료, 현재 누적 rows: 60870
# [INFO] chunk 108 처리 완료, 현재 누적 rows: 62924
# [INFO] chunk 109 처리 완료, 현재 누적 rows: 63032
# [INFO] chunk 110 처리 완료, 현재 누적 rows: 63082
# [INFO] chunk 111 처리 완료, 현재 누적 rows: 63447
# [INFO] chunk 112 처리 완료, 현재 누적 rows: 63607
# [INFO] chunk 113 처리 완료, 현재 누적 rows: 65028
# [INFO] chunk 114 처리 완료, 현재 누적 rows: 65374
# [INFO] chunk 115 처리 완료, 현재 누적 rows: 65563
# [INFO] chunk 116 처리 완료, 현재 누적 rows: 66181
# [INFO] chunk 117 처리 완료, 현재 누적 rows: 66883
# [INFO] chunk 118 처리 완료, 현재 누적 rows: 67148
# [INFO] chunk 119 처리 완료, 현재 누적 rows: 67234
# [INFO] chunk 120 처리 완료, 현재 누적 rows: 67770
# [INFO] chunk 121 처리 완료, 현재 누적 rows: 67819
# [INFO] chunk 122 처리 완료, 현재 누적 rows: 68008
# [INFO] chunk 123 처리 완료, 현재 누적 rows: 68707
# [INFO] chunk 124 처리 완료, 현재 누적 rows: 69304
# [INFO] chunk 125 처리 완료, 현재 누적 rows: 71861
# [INFO] chunk 126 처리 완료, 현재 누적 rows: 71888
# [INFO] chunk 127 처리 완료, 현재 누적 rows: 72028
# [INFO] chunk 128 처리 완료, 현재 누적 rows: 72074
# [INFO] chunk 129 처리 완료, 현재 누적 rows: 72984
# [INFO] chunk 130 처리 완료, 현재 누적 rows: 74194
# [INFO] chunk 131 처리 완료, 현재 누적 rows: 74546
# [INFO] chunk 132 처리 완료, 현재 누적 rows: 75745
# [INFO] chunk 133 처리 완료, 현재 누적 rows: 75846
# [INFO] chunk 134 처리 완료, 현재 누적 rows: 76663
# [INFO] chunk 135 처리 완료, 현재 누적 rows: 76987
# [INFO] chunk 136 처리 완료, 현재 누적 rows: 77122
# [INFO] chunk 137 처리 완료, 현재 누적 rows: 79083
# [INFO] chunk 138 처리 완료, 현재 누적 rows: 81185
# [INFO] chunk 139 처리 완료, 현재 누적 rows: 81965
# [INFO] chunk 140 처리 완료, 현재 누적 rows: 82841
# [INFO] chunk 141 처리 완료, 현재 누적 rows: 84532
# [INFO] chunk 142 처리 완료, 현재 누적 rows: 84579
# [INFO] chunk 143 처리 완료, 현재 누적 rows: 85158
# [INFO] chunk 144 처리 완료, 현재 누적 rows: 86396
# [INFO] chunk 145 처리 완료, 현재 누적 rows: 87825
# [INFO] chunk 146 처리 완료, 현재 누적 rows: 87956
# [INFO] chunk 147 처리 완료, 현재 누적 rows: 88071
# [INFO] chunk 148 처리 완료, 현재 누적 rows: 89927
# [INFO] chunk 149 처리 완료, 현재 누적 rows: 90449
# [INFO] chunk 151 처리 완료, 현재 누적 rows: 90531
# [INFO] chunk 152 처리 완료, 현재 누적 rows: 93041
# [INFO] chunk 153 처리 완료, 현재 누적 rows: 93639
# [INFO] chunk 154 처리 완료, 현재 누적 rows: 94090
# [INFO] chunk 155 처리 완료, 현재 누적 rows: 94390
# [INFO] chunk 156 처리 완료, 현재 누적 rows: 94892
# [INFO] chunk 157 처리 완료, 현재 누적 rows: 94998
# [INFO] chunk 158 처리 완료, 현재 누적 rows: 95017
# [INFO] chunk 159 처리 완료, 현재 누적 rows: 95400
# [INFO] chunk 160 처리 완료, 현재 누적 rows: 95646
# [INFO] chunk 161 처리 완료, 현재 누적 rows: 97193
# [INFO] chunk 162 처리 완료, 현재 누적 rows: 97858
# [INFO] chunk 163 처리 완료, 현재 누적 rows: 97922
# [INFO] chunk 164 처리 완료, 현재 누적 rows: 98391
# [INFO] chunk 165 처리 완료, 현재 누적 rows: 98811
# [INFO] chunk 166 처리 완료, 현재 누적 rows: 98978
# [INFO] chunk 167 처리 완료, 현재 누적 rows: 99221
# [INFO] chunk 168 처리 완료, 현재 누적 rows: 99315
# [INFO] chunk 170 처리 완료, 현재 누적 rows: 99386
# [INFO] chunk 171 처리 완료, 현재 누적 rows: 100851
# [INFO] chunk 172 처리 완료, 현재 누적 rows: 101085
# [INFO] chunk 173 처리 완료, 현재 누적 rows: 102519
# [INFO] chunk 174 처리 완료, 현재 누적 rows: 102729
# [INFO] chunk 177 처리 완료, 현재 누적 rows: 103092
# [INFO] chunk 178 처리 완료, 현재 누적 rows: 104422
# [INFO] chunk 179 처리 완료, 현재 누적 rows: 104639
# [INFO] chunk 180 처리 완료, 현재 누적 rows: 106637
# [INFO] chunk 181 처리 완료, 현재 누적 rows: 107700
# [INFO] chunk 182 처리 완료, 현재 누적 rows: 108317
# [INFO] chunk 183 처리 완료, 현재 누적 rows: 109010
# [INFO] chunk 184 처리 완료, 현재 누적 rows: 109385
# [INFO] chunk 185 처리 완료, 현재 누적 rows: 109792
# [INFO] chunk 186 처리 완료, 현재 누적 rows: 111574
# [INFO] chunk 187 처리 완료, 현재 누적 rows: 111966
# [INFO] chunk 188 처리 완료, 현재 누적 rows: 112981
# [INFO] chunk 189 처리 완료, 현재 누적 rows: 113533
# [INFO] chunk 190 처리 완료, 현재 누적 rows: 113696
# [INFO] chunk 191 처리 완료, 현재 누적 rows: 114789
# [INFO] chunk 192 처리 완료, 현재 누적 rows: 115650
# [INFO] chunk 193 처리 완료, 현재 누적 rows: 116469
# [INFO] chunk 194 처리 완료, 현재 누적 rows: 116655
# [INFO] chunk 195 처리 완료, 현재 누적 rows: 117007
# [INFO] chunk 196 처리 완료, 현재 누적 rows: 118162
# [INFO] chunk 197 처리 완료, 현재 누적 rows: 118357
# [INFO] chunk 198 처리 완료, 현재 누적 rows: 118478
# [INFO] chunk 199 처리 완료, 현재 누적 rows: 119353
# [INFO] chunk 200 처리 완료, 현재 누적 rows: 119602
# [INFO] chunk 201 처리 완료, 현재 누적 rows: 119620
# [INFO] chunk 202 처리 완료, 현재 누적 rows: 120138
# [INFO] chunk 203 처리 완료, 현재 누적 rows: 120181
# [INFO] chunk 204 처리 완료, 현재 누적 rows: 120794
# [INFO] chunk 205 처리 완료, 현재 누적 rows: 121808
# [INFO] chunk 206 처리 완료, 현재 누적 rows: 122355
# [INFO] chunk 207 처리 완료, 현재 누적 rows: 122394
# [INFO] chunk 208 처리 완료, 현재 누적 rows: 124849
# [INFO] chunk 209 처리 완료, 현재 누적 rows: 126265
# [INFO] chunk 210 처리 완료, 현재 누적 rows: 126390
# [INFO] chunk 211 처리 완료, 현재 누적 rows: 126469
# [INFO] chunk 212 처리 완료, 현재 누적 rows: 127351
# [INFO] chunk 213 처리 완료, 현재 누적 rows: 127412
# [INFO] chunk 214 처리 완료, 현재 누적 rows: 127581
# [INFO] chunk 215 처리 완료, 현재 누적 rows: 129384
# [INFO] chunk 216 처리 완료, 현재 누적 rows: 130216
# [INFO] chunk 217 처리 완료, 현재 누적 rows: 130298
# [INFO] chunk 218 처리 완료, 현재 누적 rows: 130514
# [INFO] chunk 220 처리 완료, 현재 누적 rows: 131025
# [INFO] chunk 222 처리 완료, 현재 누적 rows: 131375
# [INFO] chunk 223 처리 완료, 현재 누적 rows: 131624
# [INFO] chunk 224 처리 완료, 현재 누적 rows: 131995
# [INFO] chunk 225 처리 완료, 현재 누적 rows: 134820
# [INFO] chunk 226 처리 완료, 현재 누적 rows: 135154
# [INFO] chunk 227 처리 완료, 현재 누적 rows: 135402
# [INFO] chunk 228 처리 완료, 현재 누적 rows: 135591
# [INFO] chunk 229 처리 완료, 현재 누적 rows: 136383
# [INFO] chunk 230 처리 완료, 현재 누적 rows: 136869
# [INFO] chunk 231 처리 완료, 현재 누적 rows: 136981
# [INFO] chunk 233 처리 완료, 현재 누적 rows: 137300
# [INFO] chunk 234 처리 완료, 현재 누적 rows: 137516
# [INFO] chunk 235 처리 완료, 현재 누적 rows: 138365
# [INFO] chunk 236 처리 완료, 현재 누적 rows: 138783
# [INFO] chunk 237 처리 완료, 현재 누적 rows: 138886
# [INFO] chunk 238 처리 완료, 현재 누적 rows: 139033
# [INFO] chunk 239 처리 완료, 현재 누적 rows: 139987
# [INFO] chunk 240 처리 완료, 현재 누적 rows: 140042
# [INFO] chunk 241 처리 완료, 현재 누적 rows: 141473
# [INFO] chunk 242 처리 완료, 현재 누적 rows: 141872
# [INFO] chunk 243 처리 완료, 현재 누적 rows: 142509
# [INFO] chunk 244 처리 완료, 현재 누적 rows: 145273
# [INFO] chunk 245 처리 완료, 현재 누적 rows: 145382
# [INFO] chunk 246 처리 완료, 현재 누적 rows: 147039
# [INFO] chunk 247 처리 완료, 현재 누적 rows: 148387
# [INFO] chunk 248 처리 완료, 현재 누적 rows: 149401
# [INFO] chunk 249 처리 완료, 현재 누적 rows: 151174
# [INFO] chunk 251 처리 완료, 현재 누적 rows: 153557
# [INFO] chunk 252 처리 완료, 현재 누적 rows: 153963
# [INFO] chunk 253 처리 완료, 현재 누적 rows: 154795
# [INFO] chunk 254 처리 완료, 현재 누적 rows: 157264
# [INFO] chunk 255 처리 완료, 현재 누적 rows: 157353
# [INFO] chunk 256 처리 완료, 현재 누적 rows: 158573
# [INFO] chunk 257 처리 완료, 현재 누적 rows: 158979
# [INFO] chunk 258 처리 완료, 현재 누적 rows: 159092
# [INFO] chunk 259 처리 완료, 현재 누적 rows: 159764
# [INFO] chunk 260 처리 완료, 현재 누적 rows: 159926
# [INFO] chunk 261 처리 완료, 현재 누적 rows: 160393
# [INFO] chunk 262 처리 완료, 현재 누적 rows: 160865
# [INFO] chunk 263 처리 완료, 현재 누적 rows: 160919
# [INFO] chunk 265 처리 완료, 현재 누적 rows: 161025
# [INFO] chunk 266 처리 완료, 현재 누적 rows: 161498
# [INFO] chunk 267 처리 완료, 현재 누적 rows: 161712
# [INFO] chunk 268 처리 완료, 현재 누적 rows: 162903
# [INFO] chunk 269 처리 완료, 현재 누적 rows: 163456
# [INFO] chunk 271 처리 완료, 현재 누적 rows: 164871
# [INFO] chunk 272 처리 완료, 현재 누적 rows: 164975
# [INFO] chunk 273 처리 완료, 현재 누적 rows: 166113
# [INFO] chunk 275 처리 완료, 현재 누적 rows: 168265
# [INFO] chunk 277 처리 완료, 현재 누적 rows: 169051
# [INFO] chunk 278 처리 완료, 현재 누적 rows: 169321
# [INFO] chunk 279 처리 완료, 현재 누적 rows: 169803
# [INFO] chunk 280 처리 완료, 현재 누적 rows: 170139
# [INFO] chunk 281 처리 완료, 현재 누적 rows: 170783
# [INFO] chunk 282 처리 완료, 현재 누적 rows: 170921
# [INFO] chunk 283 처리 완료, 현재 누적 rows: 171047
# [INFO] chunk 284 처리 완료, 현재 누적 rows: 171235
# [INFO] chunk 285 처리 완료, 현재 누적 rows: 171560
# [INFO] chunk 286 처리 완료, 현재 누적 rows: 172455
# [INFO] chunk 287 처리 완료, 현재 누적 rows: 172856
# [INFO] chunk 288 처리 완료, 현재 누적 rows: 173185
# [INFO] chunk 289 처리 완료, 현재 누적 rows: 174363
# [INFO] chunk 290 처리 완료, 현재 누적 rows: 174737
# [INFO] chunk 291 처리 완료, 현재 누적 rows: 175021
# [INFO] chunk 292 처리 완료, 현재 누적 rows: 175292
# [INFO] chunk 293 처리 완료, 현재 누적 rows: 175547
# [INFO] chunk 294 처리 완료, 현재 누적 rows: 175773
# [INFO] chunk 295 처리 완료, 현재 누적 rows: 177401
# [INFO] chunk 296 처리 완료, 현재 누적 rows: 179081
# [INFO] chunk 297 처리 완료, 현재 누적 rows: 180143
# [INFO] chunk 298 처리 완료, 현재 누적 rows: 181015
# [INFO] chunk 299 처리 완료, 현재 누적 rows: 181242
# [INFO] chunk 300 처리 완료, 현재 누적 rows: 183058
# [INFO] chunk 301 처리 완료, 현재 누적 rows: 183415
# [INFO] chunk 302 처리 완료, 현재 누적 rows: 184682
# [INFO] chunk 303 처리 완료, 현재 누적 rows: 185539
# [INFO] chunk 304 처리 완료, 현재 누적 rows: 185584
# [INFO] chunk 305 처리 완료, 현재 누적 rows: 185632
# [INFO] chunk 306 처리 완료, 현재 누적 rows: 185992
# [INFO] chunk 307 처리 완료, 현재 누적 rows: 186254
# [INFO] chunk 308 처리 완료, 현재 누적 rows: 187714
# [INFO] chunk 309 처리 완료, 현재 누적 rows: 190621
# [INFO] chunk 310 처리 완료, 현재 누적 rows: 190774
# [INFO] chunk 311 처리 완료, 현재 누적 rows: 191401
# [INFO] chunk 312 처리 완료, 현재 누적 rows: 192703
# [INFO] chunk 313 처리 완료, 현재 누적 rows: 193530
# [INFO] chunk 314 처리 완료, 현재 누적 rows: 197499
# [INFO] chunk 315 처리 완료, 현재 누적 rows: 197681
# [INFO] chunk 316 처리 완료, 현재 누적 rows: 197751
# [INFO] chunk 317 처리 완료, 현재 누적 rows: 199338
# [INFO] chunk 318 처리 완료, 현재 누적 rows: 199534
# [INFO] chunk 319 처리 완료, 현재 누적 rows: 199615
# [INFO] chunk 321 처리 완료, 현재 누적 rows: 200516
# [INFO] chunk 322 처리 완료, 현재 누적 rows: 200813
# [INFO] chunk 323 처리 완료, 현재 누적 rows: 201285
# [INFO] chunk 324 처리 완료, 현재 누적 rows: 201393
# [INFO] chunk 325 처리 완료, 현재 누적 rows: 202845
# [INFO] chunk 326 처리 완료, 현재 누적 rows: 202880
# [INFO] chunk 327 처리 완료, 현재 누적 rows: 203164
# [INFO] chunk 328 처리 완료, 현재 누적 rows: 203362
# [INFO] chunk 329 처리 완료, 현재 누적 rows: 204397
# [INFO] chunk 330 처리 완료, 현재 누적 rows: 204754
# [INFO] chunk 331 처리 완료, 현재 누적 rows: 204941
# [INFO] chunk 332 처리 완료, 현재 누적 rows: 205319
# [INFO] chunk 333 처리 완료, 현재 누적 rows: 205553
# [INFO] chunk 334 처리 완료, 현재 누적 rows: 206839
# [INFO] chunk 335 처리 완료, 현재 누적 rows: 207081
# [INFO] chunk 336 처리 완료, 현재 누적 rows: 207222
# [INFO] chunk 337 처리 완료, 현재 누적 rows: 207966
# [INFO] chunk 338 처리 완료, 현재 누적 rows: 208366
# [INFO] chunk 339 처리 완료, 현재 누적 rows: 208486
# [INFO] chunk 340 처리 완료, 현재 누적 rows: 208715
# [INFO] chunk 341 처리 완료, 현재 누적 rows: 208891
# [INFO] chunk 342 처리 완료, 현재 누적 rows: 209217
# [INFO] chunk 343 처리 완료, 현재 누적 rows: 210783
# [INFO] chunk 344 처리 완료, 현재 누적 rows: 211457
# [INFO] chunk 345 처리 완료, 현재 누적 rows: 211886
# [INFO] chunk 346 처리 완료, 현재 누적 rows: 212247
# [INFO] chunk 347 처리 완료, 현재 누적 rows: 212374
# [INFO] chunk 348 처리 완료, 현재 누적 rows: 212750
# [INFO] chunk 349 처리 완료, 현재 누적 rows: 212921
# [INFO] chunk 350 처리 완료, 현재 누적 rows: 214012
# [INFO] chunk 351 처리 완료, 현재 누적 rows: 215308
# [INFO] chunk 352 처리 완료, 현재 누적 rows: 215343
# [INFO] chunk 355 처리 완료, 현재 누적 rows: 216989
# [INFO] chunk 356 처리 완료, 현재 누적 rows: 220429
# [INFO] chunk 357 처리 완료, 현재 누적 rows: 221435
# [INFO] chunk 358 처리 완료, 현재 누적 rows: 221446
# [INFO] chunk 359 처리 완료, 현재 누적 rows: 221612
# [INFO] chunk 360 처리 완료, 현재 누적 rows: 222158
# [INFO] chunk 361 처리 완료, 현재 누적 rows: 223076
# [INFO] chunk 362 처리 완료, 현재 누적 rows: 223161
# [INFO] chunk 363 처리 완료, 현재 누적 rows: 226021
# [INFO] chunk 364 처리 완료, 현재 누적 rows: 226327
# [INFO] chunk 365 처리 완료, 현재 누적 rows: 227175
# [INFO] chunk 366 처리 완료, 현재 누적 rows: 227373
# [INFO] chunk 367 처리 완료, 현재 누적 rows: 227539
# [INFO] chunk 368 처리 완료, 현재 누적 rows: 229995
# [INFO] chunk 369 처리 완료, 현재 누적 rows: 231905
# [INFO] chunk 370 처리 완료, 현재 누적 rows: 231981
# [INFO] chunk 371 처리 완료, 현재 누적 rows: 232164
# [INFO] chunk 372 처리 완료, 현재 누적 rows: 232800
# [INFO] chunk 373 처리 완료, 현재 누적 rows: 233082
# [INFO] chunk 374 처리 완료, 현재 누적 rows: 235426
# [INFO] chunk 375 처리 완료, 현재 누적 rows: 235633
# [INFO] chunk 377 처리 완료, 현재 누적 rows: 236147
# [INFO] chunk 378 처리 완료, 현재 누적 rows: 236307
# [INFO] chunk 379 처리 완료, 현재 누적 rows: 237181
# [INFO] chunk 380 처리 완료, 현재 누적 rows: 237223
# [INFO] chunk 381 처리 완료, 현재 누적 rows: 237951
# [INFO] chunk 382 처리 완료, 현재 누적 rows: 240137
# [INFO] chunk 384 처리 완료, 현재 누적 rows: 240424
# [INFO] chunk 385 처리 완료, 현재 누적 rows: 240556
# [INFO] chunk 386 처리 완료, 현재 누적 rows: 241077
# [INFO] chunk 387 처리 완료, 현재 누적 rows: 241312
# [INFO] chunk 388 처리 완료, 현재 누적 rows: 241409
# [INFO] chunk 389 처리 완료, 현재 누적 rows: 241839
# [INFO] chunk 390 처리 완료, 현재 누적 rows: 241963
# [INFO] chunk 391 처리 완료, 현재 누적 rows: 242241
# [INFO] chunk 392 처리 완료, 현재 누적 rows: 242734
# [INFO] chunk 393 처리 완료, 현재 누적 rows: 242958
# [INFO] chunk 394 처리 완료, 현재 누적 rows: 243137
# [INFO] chunk 395 처리 완료, 현재 누적 rows: 244166
# [INFO] chunk 396 처리 완료, 현재 누적 rows: 244369
# [INFO] chunk 397 처리 완료, 현재 누적 rows: 244859
# [INFO] chunk 398 처리 완료, 현재 누적 rows: 248202
# [INFO] chunk 399 처리 완료, 현재 누적 rows: 248334
# [INFO] chunk 400 처리 완료, 현재 누적 rows: 248820
# [INFO] chunk 401 처리 완료, 현재 누적 rows: 248869
# [INFO] chunk 402 처리 완료, 현재 누적 rows: 248894
# [INFO] chunk 403 처리 완료, 현재 누적 rows: 248957
# [INFO] chunk 404 처리 완료, 현재 누적 rows: 249426
# [INFO] chunk 405 처리 완료, 현재 누적 rows: 249809
# [INFO] chunk 406 처리 완료, 현재 누적 rows: 249840
# [INFO] chunk 407 처리 완료, 현재 누적 rows: 250528
# [INFO] chunk 408 처리 완료, 현재 누적 rows: 250979
# [INFO] chunk 409 처리 완료, 현재 누적 rows: 251330
# [INFO] chunk 411 처리 완료, 현재 누적 rows: 251408
# [INFO] chunk 412 처리 완료, 현재 누적 rows: 251721
# [INFO] chunk 413 처리 완료, 현재 누적 rows: 252630
# [INFO] chunk 414 처리 완료, 현재 누적 rows: 252975
# [INFO] chunk 415 처리 완료, 현재 누적 rows: 254324
# [INFO] chunk 416 처리 완료, 현재 누적 rows: 255143
# [INFO] chunk 417 처리 완료, 현재 누적 rows: 256503
# [INFO] chunk 418 처리 완료, 현재 누적 rows: 256517
# [INFO] chunk 419 처리 완료, 현재 누적 rows: 257525
# [INFO] chunk 420 처리 완료, 현재 누적 rows: 258162
# [INFO] chunk 421 처리 완료, 현재 누적 rows: 258243
# [INFO] chunk 422 처리 완료, 현재 누적 rows: 259231
# [INFO] chunk 423 처리 완료, 현재 누적 rows: 259573
# [INFO] chunk 424 처리 완료, 현재 누적 rows: 260450
# [INFO] chunk 425 처리 완료, 현재 누적 rows: 260684
# [INFO] chunk 427 처리 완료, 현재 누적 rows: 261665
# [INFO] chunk 429 처리 완료, 현재 누적 rows: 261902
# [INFO] chunk 430 처리 완료, 현재 누적 rows: 262770
# [INFO] chunk 431 처리 완료, 현재 누적 rows: 262923
# [INFO] chunk 432 처리 완료, 현재 누적 rows: 263686
# [DONE] 최종 vitals 저장 완료: ..\..\data\MIMIC4-hosp-icu\cohort_ver50_chartevents.csv (rows=263686)
