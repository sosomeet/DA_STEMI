# %%
import pandas as pd
import os

LABEVENTS_PATH = "../../data/MIMIC4-hosp-icu/labevents.csv"
OUTPUT_PATH = "../../data/MIMIC4-hosp-icu/labevents_troponin.csv"

TROPONIN_ITEMIDS = [52642, 51002, 51003]
CHUNKSIZE = 1_000_000  # 상황에 맞게 조정

# 기존 출력 파일이 있다면 삭제
if os.path.exists(OUTPUT_PATH):
    os.remove(OUTPUT_PATH)
    print(f"[INFO] 기존 파일 삭제: {OUTPUT_PATH}")

header_written = False
total_rows = 0

for i, chunk in enumerate(pd.read_csv(LABEVENTS_PATH, chunksize=CHUNKSIZE)):
    print(f"[INFO] chunk {i} 로딩, rows={len(chunk)}")

    # Troponin 필터링
    sub = chunk[chunk["itemid"].isin(TROPONIN_ITEMIDS)].copy()
    print(f"[INFO]   → chunk {i} Troponin rows={len(sub)}")

    if len(sub) == 0:
        continue

    mode = "a"
    header = not header_written
    sub.to_csv(OUTPUT_PATH, mode=mode, header=header, index=False)
    header_written = True

    total_rows += len(sub)

print("[INFO] 전체 Troponin row 수:", total_rows)
print("[INFO] Saved:", os.path.abspath(OUTPUT_PATH))
# Out:
# [INFO] chunk 0 로딩, rows=1000000
# [INFO]   → chunk 0 Troponin rows=2901
# [INFO] chunk 1 로딩, rows=1000000
# [INFO]   → chunk 1 Troponin rows=2949
# [INFO] chunk 2 로딩, rows=1000000
# [INFO]   → chunk 2 Troponin rows=2698
# [INFO] chunk 3 로딩, rows=1000000
# [INFO]   → chunk 3 Troponin rows=2956
# [INFO] chunk 4 로딩, rows=1000000
# [INFO]   → chunk 4 Troponin rows=2893
# [INFO] chunk 5 로딩, rows=1000000
# [INFO]   → chunk 5 Troponin rows=2884
# [INFO] chunk 6 로딩, rows=1000000
# [INFO]   → chunk 6 Troponin rows=3118
# [INFO] chunk 7 로딩, rows=1000000
# [INFO]   → chunk 7 Troponin rows=2736
# [INFO] chunk 8 로딩, rows=1000000
# [INFO]   → chunk 8 Troponin rows=2998
# [INFO] chunk 9 로딩, rows=1000000
# [INFO]   → chunk 9 Troponin rows=2848
# [INFO] chunk 10 로딩, rows=1000000
# [INFO]   → chunk 10 Troponin rows=3185
# [INFO] chunk 11 로딩, rows=1000000
# [INFO]   → chunk 11 Troponin rows=2823
# [INFO] chunk 12 로딩, rows=1000000
# [INFO]   → chunk 12 Troponin rows=2877
# [INFO] chunk 13 로딩, rows=1000000
# [INFO]   → chunk 13 Troponin rows=2886
# [INFO] chunk 14 로딩, rows=1000000
# [INFO]   → chunk 14 Troponin rows=2822
# [INFO] chunk 15 로딩, rows=1000000
# [INFO]   → chunk 15 Troponin rows=2811
# [INFO] chunk 16 로딩, rows=1000000
# [INFO]   → chunk 16 Troponin rows=3025
# [INFO] chunk 17 로딩, rows=1000000
# [INFO]   → chunk 17 Troponin rows=2790
# [INFO] chunk 18 로딩, rows=1000000
# [INFO]   → chunk 18 Troponin rows=3131
# [INFO] chunk 19 로딩, rows=1000000
# [INFO]   → chunk 19 Troponin rows=3134
# [INFO] chunk 20 로딩, rows=1000000
# [INFO]   → chunk 20 Troponin rows=3218
# [INFO] chunk 21 로딩, rows=1000000
# [INFO]   → chunk 21 Troponin rows=3161
# [INFO] chunk 22 로딩, rows=1000000
# [INFO]   → chunk 22 Troponin rows=2863
# [INFO] chunk 23 로딩, rows=1000000
# [INFO]   → chunk 23 Troponin rows=2855
# [INFO] chunk 24 로딩, rows=1000000
# [INFO]   → chunk 24 Troponin rows=2819
# [INFO] chunk 25 로딩, rows=1000000
# [INFO]   → chunk 25 Troponin rows=3004
# [INFO] chunk 26 로딩, rows=1000000
# [INFO]   → chunk 26 Troponin rows=2981
# [INFO] chunk 27 로딩, rows=1000000
# [INFO]   → chunk 27 Troponin rows=2915
# [INFO] chunk 28 로딩, rows=1000000
# [INFO]   → chunk 28 Troponin rows=3159
# [INFO] chunk 29 로딩, rows=1000000
# [INFO]   → chunk 29 Troponin rows=3058
# [INFO] chunk 30 로딩, rows=1000000
# [INFO]   → chunk 30 Troponin rows=2639
# [INFO] chunk 31 로딩, rows=1000000
# [INFO]   → chunk 31 Troponin rows=2888
# [INFO] chunk 32 로딩, rows=1000000
# [INFO]   → chunk 32 Troponin rows=2947
# [INFO] chunk 33 로딩, rows=1000000
# [INFO]   → chunk 33 Troponin rows=2873
# [INFO] chunk 34 로딩, rows=1000000
# [INFO]   → chunk 34 Troponin rows=2778
# [INFO] chunk 35 로딩, rows=1000000
# [INFO]   → chunk 35 Troponin rows=3299
# [INFO] chunk 36 로딩, rows=1000000
# [INFO]   → chunk 36 Troponin rows=2878
# [INFO] chunk 37 로딩, rows=1000000
# [INFO]   → chunk 37 Troponin rows=2815
# [INFO] chunk 38 로딩, rows=1000000
# [INFO]   → chunk 38 Troponin rows=2780
# [INFO] chunk 39 로딩, rows=1000000
# [INFO]   → chunk 39 Troponin rows=2752
# [INFO] chunk 40 로딩, rows=1000000
# [INFO]   → chunk 40 Troponin rows=2852
# [INFO] chunk 41 로딩, rows=1000000
# [INFO]   → chunk 41 Troponin rows=3045
# [INFO] chunk 42 로딩, rows=1000000
# [INFO]   → chunk 42 Troponin rows=2823
# [INFO] chunk 43 로딩, rows=1000000
# [INFO]   → chunk 43 Troponin rows=2534
# [INFO] chunk 44 로딩, rows=1000000
# [INFO]   → chunk 44 Troponin rows=2927
# [INFO] chunk 45 로딩, rows=1000000
# [INFO]   → chunk 45 Troponin rows=2746
# [INFO] chunk 46 로딩, rows=1000000
# [INFO]   → chunk 46 Troponin rows=3281
# [INFO] chunk 47 로딩, rows=1000000
# [INFO]   → chunk 47 Troponin rows=3273
# [INFO] chunk 48 로딩, rows=1000000
# [INFO]   → chunk 48 Troponin rows=2603
# [INFO] chunk 49 로딩, rows=1000000
# [INFO]   → chunk 49 Troponin rows=3024
# [INFO] chunk 50 로딩, rows=1000000
# [INFO]   → chunk 50 Troponin rows=2610
# [INFO] chunk 51 로딩, rows=1000000
# [INFO]   → chunk 51 Troponin rows=2812
# [INFO] chunk 52 로딩, rows=1000000
# [INFO]   → chunk 52 Troponin rows=2870
# [INFO] chunk 53 로딩, rows=1000000
# [INFO]   → chunk 53 Troponin rows=3049
# [INFO] chunk 54 로딩, rows=1000000
# [INFO]   → chunk 54 Troponin rows=2944
# [INFO] chunk 55 로딩, rows=1000000
# [INFO]   → chunk 55 Troponin rows=2642
# [INFO] chunk 56 로딩, rows=1000000
# [INFO]   → chunk 56 Troponin rows=2964
# [INFO] chunk 57 로딩, rows=1000000
# [INFO]   → chunk 57 Troponin rows=2928
# [INFO] chunk 58 로딩, rows=1000000
# [INFO]   → chunk 58 Troponin rows=2937
# [INFO] chunk 59 로딩, rows=1000000
# [INFO]   → chunk 59 Troponin rows=2908
# [INFO] chunk 60 로딩, rows=1000000
# [INFO]   → chunk 60 Troponin rows=2835
# [INFO] chunk 61 로딩, rows=1000000
# [INFO]   → chunk 61 Troponin rows=3040
# [INFO] chunk 62 로딩, rows=1000000
# [INFO]   → chunk 62 Troponin rows=3000
# [INFO] chunk 63 로딩, rows=1000000
# [INFO]   → chunk 63 Troponin rows=2905
# [INFO] chunk 64 로딩, rows=1000000
# [INFO]   → chunk 64 Troponin rows=2915
# [INFO] chunk 65 로딩, rows=1000000
# [INFO]   → chunk 65 Troponin rows=3214
# [INFO] chunk 66 로딩, rows=1000000
# [INFO]   → chunk 66 Troponin rows=2976
# [INFO] chunk 67 로딩, rows=1000000
# [INFO]   → chunk 67 Troponin rows=3045
# [INFO] chunk 68 로딩, rows=1000000
# [INFO]   → chunk 68 Troponin rows=2804
# [INFO] chunk 69 로딩, rows=1000000
# [INFO]   → chunk 69 Troponin rows=3017
# [INFO] chunk 70 로딩, rows=1000000
# [INFO]   → chunk 70 Troponin rows=2790
# [INFO] chunk 71 로딩, rows=1000000
# [INFO]   → chunk 71 Troponin rows=3235
# [INFO] chunk 72 로딩, rows=1000000
# [INFO]   → chunk 72 Troponin rows=3300
# [INFO] chunk 73 로딩, rows=1000000
# [INFO]   → chunk 73 Troponin rows=2838
# [INFO] chunk 74 로딩, rows=1000000
# [INFO]   → chunk 74 Troponin rows=2603
# [INFO] chunk 75 로딩, rows=1000000
# [INFO]   → chunk 75 Troponin rows=2967
# [INFO] chunk 76 로딩, rows=1000000
# [INFO]   → chunk 76 Troponin rows=2918
# [INFO] chunk 77 로딩, rows=1000000
# [INFO]   → chunk 77 Troponin rows=2962
# [INFO] chunk 78 로딩, rows=1000000
# [INFO]   → chunk 78 Troponin rows=2918
# [INFO] chunk 79 로딩, rows=1000000
# [INFO]   → chunk 79 Troponin rows=2805
# [INFO] chunk 80 로딩, rows=1000000
# [INFO]   → chunk 80 Troponin rows=2904
# [INFO] chunk 81 로딩, rows=1000000
# [INFO]   → chunk 81 Troponin rows=2971
# [INFO] chunk 82 로딩, rows=1000000
# [INFO]   → chunk 82 Troponin rows=2779
# [INFO] chunk 83 로딩, rows=1000000
# [INFO]   → chunk 83 Troponin rows=2978
# [INFO] chunk 84 로딩, rows=1000000
# [INFO]   → chunk 84 Troponin rows=3154
# [INFO] chunk 85 로딩, rows=1000000
# [INFO]   → chunk 85 Troponin rows=2972
# [INFO] chunk 86 로딩, rows=1000000
# [INFO]   → chunk 86 Troponin rows=2851
# [INFO] chunk 87 로딩, rows=1000000
# [INFO]   → chunk 87 Troponin rows=2574
# [INFO] chunk 88 로딩, rows=1000000
# [INFO]   → chunk 88 Troponin rows=2761
# [INFO] chunk 89 로딩, rows=1000000
# [INFO]   → chunk 89 Troponin rows=3005
# [INFO] chunk 90 로딩, rows=1000000
# [INFO]   → chunk 90 Troponin rows=3009
# [INFO] chunk 91 로딩, rows=1000000
# [INFO]   → chunk 91 Troponin rows=3089
# [INFO] chunk 92 로딩, rows=1000000
# [INFO]   → chunk 92 Troponin rows=2810
# [INFO] chunk 93 로딩, rows=1000000
# [INFO]   → chunk 93 Troponin rows=2946
# [INFO] chunk 94 로딩, rows=1000000
# [INFO]   → chunk 94 Troponin rows=3257
# [INFO] chunk 95 로딩, rows=1000000
# [INFO]   → chunk 95 Troponin rows=2802
# [INFO] chunk 96 로딩, rows=1000000
# [INFO]   → chunk 96 Troponin rows=2858
# [INFO] chunk 97 로딩, rows=1000000
# [INFO]   → chunk 97 Troponin rows=2744
# [INFO] chunk 98 로딩, rows=1000000
# [INFO]   → chunk 98 Troponin rows=2896
# [INFO] chunk 99 로딩, rows=1000000
# [INFO]   → chunk 99 Troponin rows=3070
# [INFO] chunk 100 로딩, rows=1000000
# [INFO]   → chunk 100 Troponin rows=2901
# [INFO] chunk 101 로딩, rows=1000000
# [INFO]   → chunk 101 Troponin rows=2767
# [INFO] chunk 102 로딩, rows=1000000
# [INFO]   → chunk 102 Troponin rows=3178
# [INFO] chunk 103 로딩, rows=1000000
# [INFO]   → chunk 103 Troponin rows=2983
# [INFO] chunk 104 로딩, rows=1000000
# [INFO]   → chunk 104 Troponin rows=2667
# [INFO] chunk 105 로딩, rows=1000000
# [INFO]   → chunk 105 Troponin rows=3114
# [INFO] chunk 106 로딩, rows=1000000
# [INFO]   → chunk 106 Troponin rows=2753
# [INFO] chunk 107 로딩, rows=1000000
# [INFO]   → chunk 107 Troponin rows=3013
# [INFO] chunk 108 로딩, rows=1000000
# [INFO]   → chunk 108 Troponin rows=2782
# [INFO] chunk 109 로딩, rows=1000000
# [INFO]   → chunk 109 Troponin rows=2774
# [INFO] chunk 110 로딩, rows=1000000
# [INFO]   → chunk 110 Troponin rows=2880
# [INFO] chunk 111 로딩, rows=1000000
# [INFO]   → chunk 111 Troponin rows=3010
# [INFO] chunk 112 로딩, rows=1000000
# [INFO]   → chunk 112 Troponin rows=2951
# [INFO] chunk 113 로딩, rows=1000000
# [INFO]   → chunk 113 Troponin rows=2993
# [INFO] chunk 114 로딩, rows=1000000
# [INFO]   → chunk 114 Troponin rows=2561
# [INFO] chunk 115 로딩, rows=1000000
# [INFO]   → chunk 115 Troponin rows=3283
# [INFO] chunk 116 로딩, rows=1000000
# [INFO]   → chunk 116 Troponin rows=2764
# [INFO] chunk 117 로딩, rows=1000000
# [INFO]   → chunk 117 Troponin rows=2802
# [INFO] chunk 118 로딩, rows=1000000
# [INFO]   → chunk 118 Troponin rows=3037
# [INFO] chunk 119 로딩, rows=1000000
# [INFO]   → chunk 119 Troponin rows=2782
# [INFO] chunk 120 로딩, rows=1000000
# [INFO]   → chunk 120 Troponin rows=2841
# [INFO] chunk 121 로딩, rows=1000000
# [INFO]   → chunk 121 Troponin rows=2611
# [INFO] chunk 122 로딩, rows=1000000
# [INFO]   → chunk 122 Troponin rows=3181
# [INFO] chunk 123 로딩, rows=1000000
# [INFO]   → chunk 123 Troponin rows=2807
# [INFO] chunk 124 로딩, rows=1000000
# [INFO]   → chunk 124 Troponin rows=2830
# [INFO] chunk 125 로딩, rows=1000000
# [INFO]   → chunk 125 Troponin rows=3048
# [INFO] chunk 126 로딩, rows=1000000
# [INFO]   → chunk 126 Troponin rows=3213
# [INFO] chunk 127 로딩, rows=1000000
# [INFO]   → chunk 127 Troponin rows=3271
# [INFO] chunk 128 로딩, rows=1000000
# [INFO]   → chunk 128 Troponin rows=2813
# [INFO] chunk 129 로딩, rows=1000000
# [INFO]   → chunk 129 Troponin rows=3255
# [INFO] chunk 130 로딩, rows=1000000
# [INFO]   → chunk 130 Troponin rows=2763
# [INFO] chunk 131 로딩, rows=1000000
# [INFO]   → chunk 131 Troponin rows=2748
# [INFO] chunk 132 로딩, rows=1000000
# [INFO]   → chunk 132 Troponin rows=2912
# [INFO] chunk 133 로딩, rows=1000000
# [INFO]   → chunk 133 Troponin rows=2834
# [INFO] chunk 134 로딩, rows=1000000
# [INFO]   → chunk 134 Troponin rows=2659
# [INFO] chunk 135 로딩, rows=1000000
# [INFO]   → chunk 135 Troponin rows=2916
# [INFO] chunk 136 로딩, rows=1000000
# [INFO]   → chunk 136 Troponin rows=2984
# [INFO] chunk 137 로딩, rows=1000000
# [INFO]   → chunk 137 Troponin rows=2720
# [INFO] chunk 138 로딩, rows=1000000
# [INFO]   → chunk 138 Troponin rows=2529
# [INFO] chunk 139 로딩, rows=1000000
# [INFO]   → chunk 139 Troponin rows=2908
# [INFO] chunk 140 로딩, rows=1000000
# [INFO]   → chunk 140 Troponin rows=2785
# [INFO] chunk 141 로딩, rows=1000000
# [INFO]   → chunk 141 Troponin rows=2662
# [INFO] chunk 142 로딩, rows=1000000
# [INFO]   → chunk 142 Troponin rows=2684
# [INFO] chunk 143 로딩, rows=1000000
# [INFO]   → chunk 143 Troponin rows=2701
# [INFO] chunk 144 로딩, rows=1000000
# [INFO]   → chunk 144 Troponin rows=2932
# [INFO] chunk 145 로딩, rows=1000000
# [INFO]   → chunk 145 Troponin rows=2904
# [INFO] chunk 146 로딩, rows=1000000
# [INFO]   → chunk 146 Troponin rows=3035
# [INFO] chunk 147 로딩, rows=1000000
# [INFO]   → chunk 147 Troponin rows=2732
# [INFO] chunk 148 로딩, rows=1000000
# [INFO]   → chunk 148 Troponin rows=2792
# [INFO] chunk 149 로딩, rows=1000000
# [INFO]   → chunk 149 Troponin rows=2757
# [INFO] chunk 150 로딩, rows=1000000
# [INFO]   → chunk 150 Troponin rows=2890
# [INFO] chunk 151 로딩, rows=1000000
# [INFO]   → chunk 151 Troponin rows=2911
# [INFO] chunk 152 로딩, rows=1000000
# [INFO]   → chunk 152 Troponin rows=2767
# [INFO] chunk 153 로딩, rows=1000000
# [INFO]   → chunk 153 Troponin rows=3089
# [INFO] chunk 154 로딩, rows=1000000
# [INFO]   → chunk 154 Troponin rows=2816
# [INFO] chunk 155 로딩, rows=1000000
# [INFO]   → chunk 155 Troponin rows=2764
# [INFO] chunk 156 로딩, rows=1000000
# [INFO]   → chunk 156 Troponin rows=2889
# [INFO] chunk 157 로딩, rows=1000000
# [INFO]   → chunk 157 Troponin rows=2953
# [INFO] chunk 158 로딩, rows=374764
# [INFO]   → chunk 158 Troponin rows=1205
# [INFO] 전체 Troponin row 수: 460542
# [INFO] Saved: d:\University\3-2\1Data_Analytics\team\data\MIMIC4-hosp-icu\labevents_troponin.csv
